# %% [markdown]
# # GPT Pretrain Notebook
#
# 이 노트북은 `src/train.py`와 `src/bpe.py`를 그대로 사용해서 최종 어휘 사전 생성과 GPT 사전학습 실행만 따로 모아둔 버전입니다.

# %% [markdown]
# ## 1. 환경설정
#
# Colab에서는 GitHub 저장소 URL과 GitHub Personal Access Token을 입력해 저장소를 clone하고 `src/`를 import 경로에 추가합니다. 로컬 VS Code에서는 현재 폴더를 프로젝트 루트로 보고 실행합니다.

# %%
# Colab: 이 셀을 가장 먼저 실행하세요.
import os
import subprocess
import sys
from pathlib import Path


def normalize_github_url(url: str) -> str:
    """Colab 입력값을 git clone에 사용할 수 있는 https URL로 정리합니다."""
    url = url.strip()
    if not url:
        raise ValueError("GitHub 저장소 URL을 입력해야 합니다.")
    if url.startswith("github.com/"):
        url = "https://" + url
    if not url.startswith("https://"):
        raise ValueError("저장소 URL은 https://github.com/... 또는 github.com/... 형식이어야 합니다.")
    url = url.rstrip("/")
    if not url.endswith(".git"):
        url += ".git"
    return url


if "google.colab" in sys.modules:
    from getpass import getpass

    repo_url = normalize_github_url(input("GitHub 저장소 URL (예: github.com/USERNAME/gpt-lab.git): "))
    token = getpass("GitHub Personal Access Token (Private 저장소인 경우 입력, 공개 저장소면 Enter): ").strip()
    clone_url = repo_url.replace("https://", f"https://{token}@") if token else repo_url
    repo_name = Path(repo_url[:-4]).name if repo_url.endswith(".git") else Path(repo_url).name
    repo_dir = Path("/content") / repo_name

    if not repo_dir.exists():
        subprocess.run(["git", "clone", clone_url, str(repo_dir)], check=True)
        subprocess.run(["git", "remote", "set-url", "origin", repo_url], cwd=repo_dir, check=True)
    else:
        print(f"이미 clone된 저장소를 사용합니다: {repo_dir}")

    os.chdir(repo_dir)
else:
    repo_dir = Path(".").resolve()

sys.path.insert(0, str(repo_dir / "src"))
print(f"Repo: {repo_dir}")
# Out:
# Repo: C:\Jungle\Jungle_GPT_lab

# %% [markdown]
# ## 2. NSMC 데이터 준비
#
# 기본 데이터는 NAVER Sentiment Movie Corpus(NSMC)입니다. `download_data.py`는 원본 TSV를 내려받고, 사전 학습용 텍스트와 감성 분류용 JSONL을 만듭니다.

# %%
from pathlib import Path

try:
    import download_data

    paths = download_data.main()
except Exception as e:
    print("데이터 준비 중 문제가 생겼습니다:", e)
    print("이미 data/ 파일이 있다면 다음 셀부터 계속 진행할 수 있습니다.")

LM_TRAIN_PATH = repo_dir / "data" / "nsmc_lm_train.txt"
LM_VAL_PATH = repo_dir / "data" / "nsmc_lm_val.txt"
print("LM train exists:", LM_TRAIN_PATH.exists(), LM_TRAIN_PATH)
print("LM val exists:", LM_VAL_PATH.exists(), LM_VAL_PATH)
# Out:
# 이미 존재합니다: c:\Jungle\Jungle_GPT_lab\data\ratings_train.txt
# 이미 존재합니다: c:\Jungle\Jungle_GPT_lab\data\ratings_test.txt
# 사전 학습 train 텍스트: c:\Jungle\Jungle_GPT_lab\data\nsmc_lm_train.txt (1,379,486자)
# 사전 학습 val 텍스트: c:\Jungle\Jungle_GPT_lab\data\nsmc_lm_val.txt (120,560자)
# 감성 분류 train: c:\Jungle\Jungle_GPT_lab\data\nsmc_sentiment_train.jsonl (137,996개)
# 감성 분류 val: c:\Jungle\Jungle_GPT_lab\data\nsmc_sentiment_val.jsonl (11,999개)
# 감성 분류 test: c:\Jungle\Jungle_GPT_lab\data\nsmc_sentiment_test.jsonl (49,997개)
# LM train exists: True C:\Jungle\Jungle_GPT_lab\data\nsmc_lm_train.txt
# LM val exists: True C:\Jungle\Jungle_GPT_lab\data\nsmc_lm_val.txt

# %%
corpus = LM_TRAIN_PATH.read_text(encoding="utf-8") if LM_TRAIN_PATH.exists() else ""
val_corpus = LM_VAL_PATH.read_text(encoding="utf-8") if LM_VAL_PATH.exists() else ""
print("train chars:", len(corpus))
print("val chars:", len(val_corpus))
print(corpus[:200])
# Out:
# train chars: 1379486
# val chars: 120560
# 개재미없다. 감독의 연출력의 한계
# 이제서야 보게된 대 명작 연출미가 정말 훌륭하다!!!!!!!!
# 소주미라클을 만들어라
# 귀여운 캐릭터들도 많이 나와서 보러 가야 겠어요..
# 블랙 코미디가 싫어요.
# 평점깎고싶다10글자
# TV시리즈가 너무재밌어서 영화는 기대안하고 봤는데 역시....최고네요
# 개인적 공감이 글쎄?
# 시작은 니시지마 때문에 봤는데 나름 괜찮은 영화 봤다고

# %% [markdown]
# ## 3. 6.5 어휘 사전 훈련
#
# 사용 파일: `data/nsmc_lm_train.txt`, `data/nsmc_lm_val.txt`
#
# 권장 순서:
# 1. `corpus[:5000]`, `vocab_size=300`으로 인코딩/디코딩 복원 확인
# 2. `corpus[:100000]`, `vocab_size=1000`으로 시간 확인
# 3. Light 또는 Basic 설정으로 확장
# 4. `tokenizer.save(path)`로 저장
# 5. 다음 실행부터는 `tokenizer.load(path)` 사용
#
# 이 노트북은 확인용 셀은 생략하고, 최종 어휘 사전만 `data/nsmc_bpe_vocab_3000.json`에 저장하는 흐름으로 구성했습니다.

# %%
import torch
from pathlib import Path

# Change only this cell when you want to re-run with different settings.
PRETRAIN_CFG = {
    "run_name": "quick_pretrain",
    "seed": 42,
    "tokenizer_vocab_size": 3000,
    "tokenizer_train_chars": 1_500_000,
    "force_rebuild_tokenizer": False,
    "force_reencode": False,
    "train_text_limit": None,
    "val_text_limit": None,
    "context_length": 128,
    "stride": 32,
    "batch_size": 4,
    "emb_dim": 256,
    "n_heads": 4,
    "n_layers": 4,
    "drop_rate": 0.2,
    "qkv_bias": False,
    "learning_rate": 1e-4,
    "weight_decay": 0.03,
    "num_epochs": 10,
    "eval_freq": 100,
    "eval_iter": 10,
    "ckpt_freq": 1,
    "num_workers": 0,
    "start_context": "영화",
    "resume_checkpoint": None,
}

PRETRAIN_CFG["device"] = "cuda" if torch.cuda.is_available() else "cpu"
PRETRAIN_CFG["tokenizer_path"] = repo_dir / "data" / f"nsmc_bpe_vocab_{PRETRAIN_CFG['tokenizer_vocab_size']}.json"
PRETRAIN_CFG["final_checkpoint_path"] = repo_dir / "checkpoints" / f"{PRETRAIN_CFG['run_name']}_final.pt"
PRETRAIN_CFG["encoded_cache_dir"] = repo_dir / "checkpoints" / "encoded_cache"

{k: str(v) if isinstance(v, Path) else v for k, v in PRETRAIN_CFG.items()}
# Out:
# {'run_name': 'quick_pretrain',
#  'seed': 42,
#  'tokenizer_vocab_size': 3000,
#  'tokenizer_train_chars': 1500000,
#  'force_rebuild_tokenizer': False,
#  'force_reencode': False,
#  'train_text_limit': None,
#  'val_text_limit': None,
#  'context_length': 128,
#  'stride': 32,
#  'batch_size': 4,
#  'emb_dim': 256,
#  'n_heads': 4,
#  'n_layers': 4,
#  'drop_rate': 0.2,
#  'qkv_bias': False,
#  'learning_rate': 0.0001,
#  'weight_decay': 0.03,
#  'num_epochs': 10,
#  'eval_freq': 100,
#  'eval_iter': 10,
#  'ckpt_freq': 1,
#  'num_workers': 0,
#  'start_context': '영화',
#  'resume_checkpoint': None,
#  'device': 'cuda',
#  'tokenizer_path': 'C:\\Jungle\\Jungle_GPT_lab\\data\\nsmc_bpe_vocab_3000.json',
#  'final_checkpoint_path': 'C:\\Jungle\\Jungle_GPT_lab\\checkpoints\\quick_pretrain_final.pt',
#  'encoded_cache_dir': 'C:\\Jungle\\Jungle_GPT_lab\\checkpoints\\encoded_cache'}

# %% [markdown]
# ## 4. 최종 어휘 사전 저장
#
# `data/nsmc_bpe_vocab_3000.json`이 이미 있으면 로드하고, 없으면 `corpus[:1_500_000]`으로 학습한 뒤 저장합니다.

# %%
import hashlib
import importlib
import json
from pathlib import Path

import bpe

importlib.reload(bpe)

cfg = PRETRAIN_CFG.copy()
vocab_path = Path(cfg["tokenizer_path"])
tokenizer_source_text = corpus if cfg["tokenizer_train_chars"] in (None, 0) else corpus[: cfg["tokenizer_train_chars"]]

print(f"[tokenizer] target path: {vocab_path}")
print(f"[tokenizer] source chars: {len(tokenizer_source_text):,}")
print(f"[tokenizer] vocab size:   {cfg['tokenizer_vocab_size']}")

if cfg["force_rebuild_tokenizer"] and vocab_path.exists():
    vocab_path.unlink()
    print(f"[tokenizer] removed old file: {vocab_path}")

tokenizer = bpe.BPETokenizer(vocab_size=cfg["tokenizer_vocab_size"])
if vocab_path.exists():
    print(f"[tokenizer] loading from {vocab_path}")
    tokenizer.load(vocab_path)
else:
    print(f"[tokenizer] training start (vocab_size={cfg['tokenizer_vocab_size']})")
    tokenizer.train(tokenizer_source_text)
    vocab_path.parent.mkdir(parents=True, exist_ok=True)
    tokenizer.save(vocab_path)
    print(f"[tokenizer] saved to {vocab_path}")

TOKENIZER_ARTIFACTS = {
    "tokenizer": tokenizer,
    "path": vocab_path,
    "source_chars": len(tokenizer_source_text),
    "vocab_size": cfg["tokenizer_vocab_size"],
}

TOKENIZER_ARTIFACTS
# Out:
# [tokenizer] target path: C:\Jungle\Jungle_GPT_lab\data\nsmc_bpe_vocab_3000.json
# [tokenizer] source chars: 1,379,486
# [tokenizer] vocab size:   3000
# [tokenizer] loading from C:\Jungle\Jungle_GPT_lab\data\nsmc_bpe_vocab_3000.json
# {'tokenizer': <bpe.BPETokenizer at 0x1b308fd6850>,
#  'path': WindowsPath('C:/Jungle/Jungle_GPT_lab/data/nsmc_bpe_vocab_3000.json'),
#  'source_chars': 1379486,
#  'vocab_size': 3000}

# %% [markdown]
# ## 5. GPT 사전학습 실행
#
# 이 셀은 `src/train.py`의 `train_model`, `load_checkpoint`, `save_checkpoint`, `evaluate_model`을 그대로 사용합니다.

# %% [markdown]
# ### 5-1. 인코딩 준비
#
# 토크나이저를 불러오고, `train_ids` / `val_ids` 캐시를 준비합니다. 같은 설정이면 캐시를 다시 사용합니다.

# %%
import hashlib
import importlib
import json
from pathlib import Path

import torch

import bpe

importlib.reload(bpe)

cfg = PRETRAIN_CFG.copy()
device = torch.device(cfg["device"])
torch.manual_seed(cfg["seed"])
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(cfg["seed"])

train_text = corpus if cfg["train_text_limit"] in (None, 0) else corpus[: cfg["train_text_limit"]]
val_text = val_corpus if cfg["val_text_limit"] in (None, 0) else val_corpus[: cfg["val_text_limit"]]
tokenizer_path = Path(cfg["tokenizer_path"])

print(f"[device] {device}")
print(f"[text] train chars: {len(train_text):,}")
print(f"[text] val chars:   {len(val_text):,}")

if not train_text or not val_text:
    raise RuntimeError("LM train/val text is empty. Check the data preparation cells first.")

if "TOKENIZER_ARTIFACTS" in globals() and Path(TOKENIZER_ARTIFACTS["path"]) == tokenizer_path:
    tokenizer = TOKENIZER_ARTIFACTS["tokenizer"]
    print(f"[tokenizer] using tokenizer from TOKENIZER_ARTIFACTS: {tokenizer_path}")
else:
    tokenizer = bpe.BPETokenizer(vocab_size=cfg["tokenizer_vocab_size"])
    if tokenizer_path.exists():
        print(f"[tokenizer] loading from {tokenizer_path}")
        tokenizer.load(tokenizer_path)
    else:
        tokenizer_source_text = corpus if cfg["tokenizer_train_chars"] in (None, 0) else corpus[: cfg["tokenizer_train_chars"]]
        print(f"[tokenizer] training start (vocab_size={cfg['tokenizer_vocab_size']})")
        tokenizer.train(tokenizer_source_text)
        tokenizer_path.parent.mkdir(parents=True, exist_ok=True)
        tokenizer.save(tokenizer_path)
        print(f"[tokenizer] saved to {tokenizer_path}")

def encode_corpus_lines(name: str, text: str, tokenizer):
    token_ids = []
    lines = text.splitlines()
    total_lines = len(lines)
    print(f"[encode:{name}] start ({total_lines:,} lines)")

    for idx, line in enumerate(lines, start=1):
        line = line.strip()
        if not line:
            continue
        token_ids.extend(tokenizer.encode(line, add_bos_eos=True))

        if idx % 5000 == 0 or idx == total_lines:
            print(f"[encode:{name}] {idx:,}/{total_lines:,} lines ({len(token_ids):,} tokens)")

    print(f"[encode:{name}] done ({len(token_ids):,} tokens)")
    return token_ids

encoded_cache_dir = Path(cfg["encoded_cache_dir"])
encoded_cache_dir.mkdir(parents=True, exist_ok=True)
cache_payload = {
    "tokenizer_path": str(tokenizer_path.resolve()),
    "tokenizer_mtime_ns": tokenizer_path.stat().st_mtime_ns if tokenizer_path.exists() else None,
    "tokenizer_vocab_size": cfg["tokenizer_vocab_size"],
    "train_text_limit": cfg["train_text_limit"],
    "val_text_limit": cfg["val_text_limit"],
    "train_chars": len(train_text),
    "val_chars": len(val_text),
    "lm_train_path": str(LM_TRAIN_PATH.resolve()),
    "lm_train_mtime_ns": LM_TRAIN_PATH.stat().st_mtime_ns if LM_TRAIN_PATH.exists() else None,
    "lm_val_path": str(LM_VAL_PATH.resolve()),
    "lm_val_mtime_ns": LM_VAL_PATH.stat().st_mtime_ns if LM_VAL_PATH.exists() else None,
}
cache_key = hashlib.sha256(json.dumps(cache_payload, sort_keys=True, ensure_ascii=False).encode("utf-8")).hexdigest()[:12]
train_ids_path = encoded_cache_dir / f"train_ids_{cache_key}.pt"
val_ids_path = encoded_cache_dir / f"val_ids_{cache_key}.pt"
print(f"[encode-cache] key: {cache_key}")
print(f"[encode-cache] train path: {train_ids_path}")
print(f"[encode-cache] val path:   {val_ids_path}")

use_cached_ids = (
    not cfg.get("force_reencode", False)
    and train_ids_path.exists()
    and val_ids_path.exists()
)

if use_cached_ids:
    print("[encode-cache] loading cached token ids")
    cached_train = torch.load(train_ids_path, map_location="cpu")
    cached_val = torch.load(val_ids_path, map_location="cpu")
    train_ids = cached_train["token_ids"] if isinstance(cached_train, dict) else cached_train
    val_ids = cached_val["token_ids"] if isinstance(cached_val, dict) else cached_val
    print(f"[encode:train] loaded ({len(train_ids):,} tokens)")
    print(f"[encode:val] loaded ({len(val_ids):,} tokens)")
else:
    if cfg.get("force_reencode", False):
        print("[encode-cache] force_reencode=True, rebuilding token ids")
    else:
        print("[encode-cache] cache miss, encoding token ids")
    train_ids = encode_corpus_lines("train", train_text, tokenizer)
    val_ids = encode_corpus_lines("val", val_text, tokenizer)
    torch.save({"token_ids": train_ids, "cache_payload": cache_payload}, train_ids_path)
    torch.save({"token_ids": val_ids, "cache_payload": cache_payload}, val_ids_path)
    print("[encode-cache] saved cached token ids")

PRETRAIN_ENCODE_ARTIFACTS = {
    "config": cfg,
    "device": device,
    "tokenizer": tokenizer,
    "tokenizer_path": tokenizer_path,
    "train_ids_path": train_ids_path,
    "val_ids_path": val_ids_path,
    "train_token_count": len(train_ids),
    "val_token_count": len(val_ids),
    "encode_cache_key": cache_key,
}

print(f"[encode-cache] ready: train={len(train_ids):,} tokens, val={len(val_ids):,} tokens")
PRETRAIN_ENCODE_ARTIFACTS
# Out:
# [device] cuda
# [text] train chars: 1,379,486
# [text] val chars:   120,560
# [tokenizer] using tokenizer from TOKENIZER_ARTIFACTS: C:\Jungle\Jungle_GPT_lab\data\nsmc_bpe_vocab_3000.json
# [encode-cache] key: d925d5e5f2e6
# [encode-cache] train path: C:\Jungle\Jungle_GPT_lab\checkpoints\encoded_cache\train_ids_d925d5e5f2e6.pt
# [encode-cache] val path:   C:\Jungle\Jungle_GPT_lab\checkpoints\encoded_cache\val_ids_d925d5e5f2e6.pt
# [encode-cache] cache miss, encoding token ids
# [encode:train] start (37,826 lines)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 104
#     100     if cfg.get("force_reencode", False):
#     101         print("[encode-cache] force_reencode=True, rebuilding token ids")
#     102     else:
#     103         print("[encode-cache] cache miss, encoding token ids")
# --> 104     train_ids = encode_corpus_lines("train", train_text, tokenizer)
#     105     val_ids = encode_corpus_lines("val", val_text, tokenizer)
#     106     torch.save({"token_ids": train_ids, "cache_payload": cache_payload}, train_ids_path)
#     107     torch.save({"token_ids": val_ids, "cache_payload": cache_payload}, val_ids_path)
#
# Cell In[49], line 55, in encode_corpus_lines(name, text, tokenizer)
#      51     for idx, line in enumerate(lines, start=1):
#      52         line = line.strip()
#      53         if not line:
#      54             continue
# ---> 55         token_ids.extend(tokenizer.encode(line, add_bos_eos=True))
#      56
#      57         if idx % 5000 == 0 or idx == total_lines:
#      58             print(f"[encode:{name}] {idx:,}/{total_lines:,} lines ({len(token_ids):,} tokens)")
#
# File C:\Jungle\Jungle_GPT_lab\src\bpe.py:191, in BPETokenizer.encode(self, text, add_bos_eos)
#     189 for i, pair in enumerate(self.merges):
#     190     next_id = NUM_BYTES + BYTE_OFFSET + i
# --> 191     ids = self._merge(ids, pair, next_id)
#     193 if add_bos_eos:
#     194     ids.insert(0, self.get_bos_id())
#
# File C:\Jungle\Jungle_GPT_lab\src\bpe.py:246, in BPETokenizer._merge(self, ids, pair, new_id)
#     244 i = 0
#     245 result = list()
# --> 246 while i < len(ids):
#     247     if (i < len(ids) - 1) and (ids[i], ids[i+1]) == pair:
#     248         result.append(new_id)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 5-2. GPT 사전학습 실행
#
# 인코딩 준비 셀에서 만든 캐시를 불러와 dataloader를 만들고 학습을 실행합니다. 모델 파라미터만 바꿀 때는 이 셀만 다시 돌리면 됩니다.

# %%
import importlib
from pathlib import Path

import torch

import dataset
import model
import train

importlib.reload(dataset)
importlib.reload(model)
importlib.reload(train)

if "PRETRAIN_ENCODE_ARTIFACTS" not in globals():
    raise RuntimeError("Run the encoding cell above first.")

cfg = PRETRAIN_CFG.copy()
encode_artifacts = PRETRAIN_ENCODE_ARTIFACTS
device = torch.device(cfg["device"])
torch.manual_seed(cfg["seed"])
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(cfg["seed"])

tokenizer = encode_artifacts["tokenizer"]
train_ids_path = Path(encode_artifacts["train_ids_path"])
val_ids_path = Path(encode_artifacts["val_ids_path"])
cache_key = encode_artifacts["encode_cache_key"]

print(f"[train] loading token ids from cache key: {cache_key}")
cached_train = torch.load(train_ids_path, map_location="cpu")
cached_val = torch.load(val_ids_path, map_location="cpu")
train_ids = cached_train["token_ids"] if isinstance(cached_train, dict) else cached_train
val_ids = cached_val["token_ids"] if isinstance(cached_val, dict) else cached_val
print(f"[train] train tokens: {len(train_ids):,}")
print(f"[train] val tokens:   {len(val_ids):,}")

train_loader = dataset.create_dataloader(
    token_ids=train_ids,
    context_length=cfg["context_length"],
    batch_size=cfg["batch_size"],
    stride=cfg["stride"],
    drop_last=True,
    shuffle=True,
    num_workers=cfg["num_workers"],
)
val_loader = dataset.create_dataloader(
    token_ids=val_ids,
    context_length=cfg["context_length"],
    batch_size=cfg["batch_size"],
    stride=cfg["context_length"],
    drop_last=False,
    shuffle=False,
    num_workers=cfg["num_workers"],
)

print(f"[loader] train batches: {len(train_loader):,}")
print(f"[loader] val batches:   {len(val_loader):,}")

model_config = {
    "vocab_size": max(tokenizer.id_to_token.keys()) + 1,
    "context_length": cfg["context_length"],
    "emb_dim": cfg["emb_dim"],
    "n_heads": cfg["n_heads"],
    "n_layers": cfg["n_layers"],
    "drop_rate": cfg["drop_rate"],
    "qkv_bias": cfg["qkv_bias"],
}
print(f"[model] config: {model_config}")

gpt = model.GPTModel(model_config).to(device)
optimizer = torch.optim.AdamW(
    gpt.parameters(),
    lr=cfg["learning_rate"],
    weight_decay=cfg["weight_decay"],
)

start_epoch = 0
global_step = 0
resume_path = cfg["resume_checkpoint"]
if resume_path:
    resume_path = Path(resume_path)
    print(f"[resume] loading from {resume_path}")
    start_epoch, global_step = train.load_checkpoint(gpt, optimizer, str(resume_path), device)
    print(f"[resume] epoch={start_epoch}, global_step={global_step}")

def calc_accuracy_loader(data_loader, model, device, num_batches=None):
    was_training = model.training
    model.eval()

    if len(data_loader) == 0:
        return float("nan")

    if num_batches is None:
        num_batches = len(data_loader)
    else:
        num_batches = min(num_batches, len(data_loader))

    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (input_batch, target_batch) in enumerate(data_loader):
            if batch_idx >= num_batches:
                break

            input_batch = input_batch.to(device)
            target_batch = target_batch.to(device)
            logits = model(input_batch)
            preds = torch.argmax(logits, dim=-1)
            correct += (preds == target_batch).sum().item()
            total += target_batch.numel()

    if was_training:
        model.train()

    return correct / total if total > 0 else float("nan")

def evaluate_metrics(model, train_loader, val_loader, device, eval_iter):
    train_loss = train.calc_loss_loader(train_loader, model, device, num_batches=eval_iter)
    val_loss = train.calc_loss_loader(val_loader, model, device, num_batches=eval_iter)
    train_acc = calc_accuracy_loader(train_loader, model, device, num_batches=eval_iter)
    val_acc = calc_accuracy_loader(val_loader, model, device, num_batches=eval_iter)
    return train_loss, val_loss, train_acc, val_acc

metric_steps = []
train_losses = []
val_losses = []
train_accs = []
val_accs = []
tokens_seen = 0

print("[train] entering custom training loop")
for epoch in range(start_epoch, cfg["num_epochs"]):
    gpt.train()

    for input_batch, target_batch in train_loader:
        optimizer.zero_grad()
        loss = train.calc_loss_batch(input_batch, target_batch, gpt, device)
        loss.backward()
        optimizer.step()

        tokens_seen += input_batch.numel()
        global_step += 1

        if cfg["eval_freq"] and global_step % cfg["eval_freq"] == 0:
            train_loss, val_loss, train_acc, val_acc = evaluate_metrics(
                gpt,
                train_loader,
                val_loader,
                device,
                cfg["eval_iter"],
            )
            metric_steps.append(global_step)
            train_losses.append(train_loss)
            val_losses.append(val_loss)
            train_accs.append(train_acc)
            val_accs.append(val_acc)
            print(
                f"Ep {epoch + 1} (Step {global_step:06d}): "
                f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}, "
                f"Train acc {train_acc:.3%}, Val acc {val_acc:.3%}"
            )

    if cfg["ckpt_freq"] and (epoch + 1) % cfg["ckpt_freq"] == 0:
        ckpt_path = repo_dir / "checkpoints" / f"ckpt_epoch_{epoch + 1}.pt"
        ckpt_path.parent.mkdir(parents=True, exist_ok=True)
        train.save_checkpoint(gpt, optimizer, epoch + 1, global_step, str(ckpt_path))

    train.generate_and_print_sample(
        gpt,
        tokenizer,
        device,
        cfg["start_context"],
        context_size=cfg["context_length"],
    )

print("[train] finished")

final_train_loss, final_val_loss, final_train_acc, final_val_acc = evaluate_metrics(
    gpt,
    train_loader,
    val_loader,
    device,
    cfg["eval_iter"],
)
final_checkpoint_path = Path(cfg["final_checkpoint_path"])
final_checkpoint_path.parent.mkdir(parents=True, exist_ok=True)
final_global_step = global_step + len(train_loader) * max(0, cfg["num_epochs"] - start_epoch)
train.save_checkpoint(gpt, optimizer, cfg["num_epochs"], final_global_step, str(final_checkpoint_path))
print(f"[checkpoint] final model saved to {final_checkpoint_path}")

PRETRAIN_ARTIFACTS = {
    "config": cfg,
    "model_config": model_config,
    "tokenizer": tokenizer,
    "model": gpt,
    "train_loader": train_loader,
    "val_loader": val_loader,
    "metric_steps": metric_steps,
    "tokens_seen": tokens_seen,
    "train_losses": train_losses,
    "val_losses": val_losses,
    "train_accs": train_accs,
    "val_accs": val_accs,
    "final_train_loss": final_train_loss,
    "final_val_loss": final_val_loss,
    "final_train_acc": final_train_acc,
    "final_val_acc": final_val_acc,
    "train_ids_path": train_ids_path,
    "val_ids_path": val_ids_path,
    "encode_cache_key": cache_key,
    "checkpoint_path": final_checkpoint_path,
}

print(f"[summary] eval points: {len(train_losses)}")
print(f"[summary] final train loss: {final_train_loss:.4f}")
print(f"[summary] final val loss:   {final_val_loss:.4f}")
print(f"[summary] final train acc:  {final_train_acc:.3%}")
print(f"[summary] final val acc:    {final_val_acc:.3%}")
# Out:
# [train] loading token ids from cache key: 515ec2332c45
# [train] train tokens: 869,883
# [train] val tokens:   76,010
# [loader] train batches: 6,795
# [loader] val batches:   149
# [model] config: {'vocab_size': 3000, 'context_length': 128, 'emb_dim': 256, 'n_heads': 4, 'n_layers': 4, 'drop_rate': 0.2, 'qkv_bias': False}
# [train] entering custom training loop
# Ep 1 (Step 000100): Train loss 6.973, Val loss 6.964, Train acc 8.574%, Val acc 8.789%
# Ep 1 (Step 000200): Train loss 6.792, Val loss 6.821, Train acc 8.984%, Val acc 8.789%
# Ep 1 (Step 000300): Train loss 6.809, Val loss 6.795, Train acc 8.691%, Val acc 8.867%
# Ep 1 (Step 000400): Train loss 6.768, Val loss 6.778, Train acc 9.590%, Val acc 8.887%
# Ep 1 (Step 000500): Train loss 6.780, Val loss 6.760, Train acc 7.832%, Val acc 8.887%
# Ep 1 (Step 000600): Train loss 6.765, Val loss 6.747, Train acc 8.828%, Val acc 8.965%
# Ep 1 (Step 000700): Train loss 6.680, Val loss 6.731, Train acc 8.320%, Val acc 8.926%
# Ep 1 (Step 000800): Train loss 6.758, Val loss 6.718, Train acc 9.668%, Val acc 8.945%
# Ep 1 (Step 000900): Train loss 6.647, Val loss 6.705, Train acc 8.242%, Val acc 8.828%
# Ep 1 (Step 001000): Train loss 6.713, Val loss 6.686, Train acc 9.160%, Val acc 8.945%
# Ep 1 (Step 001100): Train loss 6.648, Val loss 6.678, Train acc 9.453%, Val acc 8.828%
# Ep 1 (Step 001200): Train loss 6.654, Val loss 6.653, Train acc 8.770%, Val acc 8.984%
# Ep 1 (Step 001300): Train loss 6.602, Val loss 6.626, Train acc 9.414%, Val acc 9.277%
# Ep 1 (Step 001400): Train loss 6.590, Val loss 6.603, Train acc 9.512%, Val acc 9.160%
# Ep 1 (Step 001500): Train loss 6.595, Val loss 6.577, Train acc 8.516%, Val acc 9.180%
# Ep 1 (Step 001600): Train loss 6.572, Val loss 6.563, Train acc 8.203%, Val acc 9.277%
# Ep 1 (Step 001700): Train loss 6.605, Val loss 6.517, Train acc 8.828%, Val acc 9.219%
# Ep 1 (Step 001800): Train loss 6.407, Val loss 6.497, Train acc 9.980%, Val acc 9.199%
# Ep 1 (Step 001900): Train loss 6.474, Val loss 6.474, Train acc 9.844%, Val acc 9.590%
# Ep 1 (Step 002000): Train loss 6.435, Val loss 6.441, Train acc 10.508%, Val acc 9.434%
# Ep 1 (Step 002100): Train loss 6.444, Val loss 6.399, Train acc 10.586%, Val acc 9.922%
# Ep 1 (Step 002200): Train loss 6.349, Val loss 6.376, Train acc 10.000%, Val acc 9.980%
# Ep 1 (Step 002300): Train loss 6.321, Val loss 6.337, Train acc 10.234%, Val acc 9.961%
# Ep 1 (Step 002400): Train loss 6.304, Val loss 6.313, Train acc 10.078%, Val acc 10.410%
# Ep 1 (Step 002500): Train loss 6.311, Val loss 6.293, Train acc 10.527%, Val acc 10.371%
# Ep 1 (Step 002600): Train loss 6.214, Val loss 6.270, Train acc 10.781%, Val acc 10.430%
# Ep 1 (Step 002700): Train loss 6.220, Val loss 6.226, Train acc 10.410%, Val acc 10.723%
# Ep 1 (Step 002800): Train loss 6.171, Val loss 6.190, Train acc 10.781%, Val acc 10.605%
# Ep 1 (Step 002900): Train loss 6.105, Val loss 6.184, Train acc 11.387%, Val acc 10.723%
# Ep 1 (Step 003000): Train loss 6.108, Val loss 6.156, Train acc 12.109%, Val acc 10.801%
# Ep 1 (Step 003100): Train loss 6.046, Val loss 6.116, Train acc 11.055%, Val acc 11.055%
# Ep 1 (Step 003200): Train loss 6.002, Val loss 6.092, Train acc 12.734%, Val acc 11.270%
# Ep 1 (Step 003300): Train loss 5.993, Val loss 6.065, Train acc 11.660%, Val acc 11.191%
# Ep 1 (Step 003400): Train loss 6.012, Val loss 6.042, Train acc 11.309%, Val acc 11.504%
# Ep 1 (Step 003500): Train loss 6.022, Val loss 6.011, Train acc 12.246%, Val acc 11.719%
# Ep 1 (Step 003600): Train loss 5.910, Val loss 5.996, Train acc 12.129%, Val acc 11.973%
# Ep 1 (Step 003700): Train loss 5.906, Val loss 5.970, Train acc 12.656%, Val acc 11.914%
# Ep 1 (Step 003800): Train loss 5.869, Val loss 5.955, Train acc 13.652%, Val acc 12.090%
# Ep 1 (Step 003900): Train loss 5.883, Val loss 5.929, Train acc 12.266%, Val acc 12.383%
# Ep 1 (Step 004000): Train loss 5.856, Val loss 5.924, Train acc 11.914%, Val acc 12.559%
# Ep 1 (Step 004100): Train loss 5.782, Val loss 5.889, Train acc 13.320%, Val acc 12.461%
# Ep 1 (Step 004200): Train loss 5.759, Val loss 5.868, Train acc 14.082%, Val acc 12.969%
# Ep 1 (Step 004300): Train loss 5.748, Val loss 5.853, Train acc 13.359%, Val acc 13.086%
# Ep 1 (Step 004400): Train loss 5.764, Val loss 5.839, Train acc 12.344%, Val acc 12.852%
# Ep 1 (Step 004500): Train loss 5.718, Val loss 5.813, Train acc 13.691%, Val acc 12.949%
# Ep 1 (Step 004600): Train loss 5.762, Val loss 5.798, Train acc 13.105%, Val acc 13.105%
# Ep 1 (Step 004700): Train loss 5.745, Val loss 5.783, Train acc 14.492%, Val acc 13.145%
# Ep 1 (Step 004800): Train loss 5.667, Val loss 5.766, Train acc 13.594%, Val acc 13.262%
# Ep 1 (Step 004900): Train loss 5.681, Val loss 5.772, Train acc 13.457%, Val acc 13.418%
# Ep 1 (Step 005000): Train loss 5.705, Val loss 5.743, Train acc 13.516%, Val acc 13.340%
# Ep 1 (Step 005100): Train loss 5.671, Val loss 5.715, Train acc 14.180%, Val acc 13.652%
# Ep 1 (Step 005200): Train loss 5.629, Val loss 5.716, Train acc 14.961%, Val acc 13.633%
# Ep 1 (Step 005300): Train loss 5.626, Val loss 5.711, Train acc 14.805%, Val acc 13.711%
# Ep 1 (Step 005400): Train loss 5.590, Val loss 5.685, Train acc 14.453%, Val acc 13.809%
# Ep 1 (Step 005500): Train loss 5.563, Val loss 5.675, Train acc 14.238%, Val acc 13.672%
# Ep 1 (Step 005600): Train loss 5.586, Val loss 5.669, Train acc 13.965%, Val acc 13.672%
# Ep 1 (Step 005700): Train loss 5.532, Val loss 5.653, Train acc 15.430%, Val acc 13.809%
# Ep 1 (Step 005800): Train loss 5.622, Val loss 5.651, Train acc 15.332%, Val acc 14.023%
# Ep 1 (Step 005900): Train loss 5.564, Val loss 5.637, Train acc 14.473%, Val acc 13.691%
# Ep 1 (Step 006000): Train loss 5.457, Val loss 5.612, Train acc 14.277%, Val acc 13.867%
# Ep 1 (Step 006100): Train loss 5.523, Val loss 5.627, Train acc 15.273%, Val acc 13.789%
# Ep 1 (Step 006200): Train loss 5.559, Val loss 5.599, Train acc 15.176%, Val acc 13.633%
# Ep 1 (Step 006300): Train loss 5.520, Val loss 5.604, Train acc 14.922%, Val acc 13.828%
# Ep 1 (Step 006400): Train loss 5.513, Val loss 5.585, Train acc 15.410%, Val acc 14.121%
# Ep 1 (Step 006500): Train loss 5.490, Val loss 5.579, Train acc 14.316%, Val acc 14.082%
# Ep 1 (Step 006600): Train loss 5.481, Val loss 5.563, Train acc 14.727%, Val acc 13.906%
# Ep 1 (Step 006700): Train loss 5.427, Val loss 5.550, Train acc 15.039%, Val acc 14.180%
# 영화중에 좀 가행에 이런데...완전 재미있는지이비디오만 한 사람을 느끼다는것도 나타진 작품솔직히 별로서도 많음시는 참 좋았음.아픈 영화
# Ep 2 (Step 006800): Train loss 5.546, Val loss 5.551, Train acc 15.410%, Val acc 13.789%
# Ep 2 (Step 006900): Train loss 5.444, Val loss 5.552, Train acc 15.898%, Val acc 13.887%
# Ep 2 (Step 007000): Train loss 5.413, Val loss 5.537, Train acc 15.820%, Val acc 13.887%
# Ep 2 (Step 007100): Train loss 5.416, Val loss 5.516, Train acc 15.410%, Val acc 14.082%
# Ep 2 (Step 007200): Train loss 5.464, Val loss 5.529, Train acc 15.664%, Val acc 14.180%
# Ep 2 (Step 007300): Train loss 5.419, Val loss 5.513, Train acc 14.902%, Val acc 14.062%
# Ep 2 (Step 007400): Train loss 5.390, Val loss 5.508, Train acc 14.668%, Val acc 14.043%
# Ep 2 (Step 007500): Train loss 5.431, Val loss 5.495, Train acc 14.844%, Val acc 14.102%
# Ep 2 (Step 007600): Train loss 5.414, Val loss 5.496, Train acc 15.625%, Val acc 14.336%
# Ep 2 (Step 007700): Train loss 5.385, Val loss 5.500, Train acc 16.562%, Val acc 14.199%
# Ep 2 (Step 007800): Train loss 5.409, Val loss 5.484, Train acc 15.840%, Val acc 14.160%
# Ep 2 (Step 007900): Train loss 5.377, Val loss 5.487, Train acc 15.137%, Val acc 14.473%
# Ep 2 (Step 008000): Train loss 5.360, Val loss 5.476, Train acc 16.250%, Val acc 14.551%
# Ep 2 (Step 008100): Train loss 5.420, Val loss 5.469, Train acc 15.840%, Val acc 14.395%
# Ep 2 (Step 008200): Train loss 5.420, Val loss 5.460, Train acc 14.824%, Val acc 14.355%
# Ep 2 (Step 008300): Train loss 5.269, Val loss 5.466, Train acc 14.922%, Val acc 14.434%
# Ep 2 (Step 008400): Train loss 5.282, Val loss 5.442, Train acc 15.156%, Val acc 14.434%
# Ep 2 (Step 008500): Train loss 5.415, Val loss 5.441, Train acc 15.977%, Val acc 14.473%
# Ep 2 (Step 008600): Train loss 5.325, Val loss 5.440, Train acc 16.035%, Val acc 14.492%
# Ep 2 (Step 008700): Train loss 5.211, Val loss 5.438, Train acc 15.605%, Val acc 14.531%
# Ep 2 (Step 008800): Train loss 5.366, Val loss 5.423, Train acc 15.723%, Val acc 14.395%
# Ep 2 (Step 008900): Train loss 5.274, Val loss 5.413, Train acc 15.039%, Val acc 14.453%
# Ep 2 (Step 009000): Train loss 5.231, Val loss 5.412, Train acc 15.156%, Val acc 14.512%
# Ep 2 (Step 009100): Train loss 5.272, Val loss 5.394, Train acc 15.313%, Val acc 14.531%
# Ep 2 (Step 009200): Train loss 5.294, Val loss 5.396, Train acc 16.270%, Val acc 14.824%
# Ep 2 (Step 009300): Train loss 5.296, Val loss 5.395, Train acc 15.879%, Val acc 14.590%
# Ep 2 (Step 009400): Train loss 5.261, Val loss 5.396, Train acc 15.547%, Val acc 14.590%
# Ep 2 (Step 009500): Train loss 5.315, Val loss 5.383, Train acc 16.289%, Val acc 14.609%
# Ep 2 (Step 009600): Train loss 5.287, Val loss 5.384, Train acc 15.918%, Val acc 14.434%
# Ep 2 (Step 009700): Train loss 5.259, Val loss 5.379, Train acc 16.895%, Val acc 14.512%
# Ep 2 (Step 009800): Train loss 5.212, Val loss 5.374, Train acc 14.648%, Val acc 14.160%
# Ep 2 (Step 009900): Train loss 5.200, Val loss 5.372, Train acc 16.348%, Val acc 14.668%
# Ep 2 (Step 010000): Train loss 5.189, Val loss 5.361, Train acc 15.996%, Val acc 14.551%
# Ep 2 (Step 010100): Train loss 5.275, Val loss 5.365, Train acc 15.254%, Val acc 14.551%
# Ep 2 (Step 010200): Train loss 5.225, Val loss 5.351, Train acc 15.586%, Val acc 14.727%
# Ep 2 (Step 010300): Train loss 5.210, Val loss 5.358, Train acc 14.922%, Val acc 14.785%
# Ep 2 (Step 010400): Train loss 5.209, Val loss 5.353, Train acc 15.664%, Val acc 14.688%
# Ep 2 (Step 010500): Train loss 5.198, Val loss 5.343, Train acc 16.289%, Val acc 14.863%
# Ep 2 (Step 010600): Train loss 5.239, Val loss 5.348, Train acc 15.859%, Val acc 14.922%
# Ep 2 (Step 010700): Train loss 5.216, Val loss 5.344, Train acc 16.211%, Val acc 14.844%
# Ep 2 (Step 010800): Train loss 5.172, Val loss 5.324, Train acc 15.820%, Val acc 14.785%
# Ep 2 (Step 010900): Train loss 5.249, Val loss 5.334, Train acc 15.762%, Val acc 14.688%
# Ep 2 (Step 011000): Train loss 5.246, Val loss 5.322, Train acc 15.742%, Val acc 14.863%
# Ep 2 (Step 011100): Train loss 5.247, Val loss 5.321, Train acc 15.371%, Val acc 15.020%
# Ep 2 (Step 011200): Train loss 5.280, Val loss 5.321, Train acc 16.465%, Val acc 15.156%
# Ep 2 (Step 011300): Train loss 5.148, Val loss 5.304, Train acc 16.289%, Val acc 15.137%
# Ep 2 (Step 011400): Train loss 5.196, Val loss 5.313, Train acc 15.449%, Val acc 14.824%
# Ep 2 (Step 011500): Train loss 5.150, Val loss 5.303, Train acc 15.859%, Val acc 14.551%
# Ep 2 (Step 011600): Train loss 5.221, Val loss 5.324, Train acc 16.152%, Val acc 14.902%
# Ep 2 (Step 011700): Train loss 5.152, Val loss 5.293, Train acc 15.684%, Val acc 14.941%
# Ep 2 (Step 011800): Train loss 5.107, Val loss 5.295, Train acc 15.469%, Val acc 14.863%
# Ep 2 (Step 011900): Train loss 5.121, Val loss 5.286, Train acc 15.977%, Val acc 15.059%
# Ep 2 (Step 012000): Train loss 5.100, Val loss 5.281, Train acc 15.957%, Val acc 14.980%
# Ep 2 (Step 012100): Train loss 5.228, Val loss 5.286, Train acc 16.426%, Val acc 15.117%
# Ep 2 (Step 012200): Train loss 5.154, Val loss 5.290, Train acc 16.016%, Val acc 15.215%
# Ep 2 (Step 012300): Train loss 5.089, Val loss 5.284, Train acc 17.285%, Val acc 14.824%
# Ep 2 (Step 012400): Train loss 5.202, Val loss 5.269, Train acc 16.465%, Val acc 15.156%
# Ep 2 (Step 012500): Train loss 5.073, Val loss 5.272, Train acc 17.148%, Val acc 15.176%
# Ep 2 (Step 012600): Train loss 5.169, Val loss 5.268, Train acc 16.270%, Val acc 15.293%
# Ep 2 (Step 012700): Train loss 5.176, Val loss 5.267, Train acc 16.152%, Val acc 15.098%
# Ep 2 (Step 012800): Train loss 5.072, Val loss 5.260, Train acc 16.523%, Val acc 15.332%
# Ep 2 (Step 012900): Train loss 5.071, Val loss 5.265, Train acc 16.973%, Val acc 15.195%
# Ep 2 (Step 013000): Train loss 5.181, Val loss 5.273, Train acc 15.937%, Val acc 15.137%
# Ep 2 (Step 013100): Train loss 5.045, Val loss 5.255, Train acc 16.133%, Val acc 15.234%
# Ep 2 (Step 013200): Train loss 5.123, Val loss 5.244, Train acc 17.109%, Val acc 15.137%
# Ep 2 (Step 013300): Train loss 5.110, Val loss 5.257, Train acc 15.937%, Val acc 15.078%
# Ep 2 (Step 013400): Train loss 5.086, Val loss 5.253, Train acc 16.348%, Val acc 15.098%
# Ep 2 (Step 013500): Train loss 5.145, Val loss 5.247, Train acc 16.738%, Val acc 15.156%
# 영화어린다재밌는데 DVDVDVD이게 왜 1대를 보는 영화.내준다.원작은 왜 만든 영화였음난다어지고 설
# Ep 3 (Step 013600): Train loss 5.045, Val loss 5.255, Train acc 15.937%, Val acc 15.156%
# Ep 3 (Step 013700): Train loss 5.120, Val loss 5.252, Train acc 17.051%, Val acc 15.391%
# Ep 3 (Step 013800): Train loss 5.074, Val loss 5.245, Train acc 15.762%, Val acc 15.371%
# Ep 3 (Step 013900): Train loss 5.066, Val loss 5.231, Train acc 16.465%, Val acc 15.313%
# Ep 3 (Step 014000): Train loss 5.095, Val loss 5.226, Train acc 15.703%, Val acc 15.156%
# Ep 3 (Step 014100): Train loss 5.063, Val loss 5.232, Train acc 16.289%, Val acc 15.234%
# Ep 3 (Step 014200): Train loss 5.105, Val loss 5.233, Train acc 16.133%, Val acc 15.371%
# Ep 3 (Step 014300): Train loss 5.041, Val loss 5.216, Train acc 15.039%, Val acc 15.410%
# Ep 3 (Step 014400): Train loss 5.048, Val loss 5.218, Train acc 16.641%, Val acc 15.371%
# Ep 3 (Step 014500): Train loss 5.072, Val loss 5.211, Train acc 15.332%, Val acc 15.410%
# Ep 3 (Step 014600): Train loss 5.058, Val loss 5.210, Train acc 16.758%, Val acc 15.547%
# Ep 3 (Step 014700): Train loss 5.184, Val loss 5.221, Train acc 16.055%, Val acc 15.234%
# Ep 3 (Step 014800): Train loss 4.987, Val loss 5.228, Train acc 15.898%, Val acc 15.254%
# Ep 3 (Step 014900): Train loss 5.130, Val loss 5.218, Train acc 16.797%, Val acc 15.020%
# Ep 3 (Step 015000): Train loss 5.015, Val loss 5.210, Train acc 16.738%, Val acc 15.586%
# Ep 3 (Step 015100): Train loss 5.034, Val loss 5.213, Train acc 16.523%, Val acc 15.332%
# Ep 3 (Step 015200): Train loss 5.031, Val loss 5.207, Train acc 17.305%, Val acc 15.508%
# Ep 3 (Step 015300): Train loss 5.094, Val loss 5.210, Train acc 16.777%, Val acc 15.625%
# Ep 3 (Step 015400): Train loss 5.073, Val loss 5.203, Train acc 15.957%, Val acc 15.664%
# Ep 3 (Step 015500): Train loss 5.049, Val loss 5.208, Train acc 17.012%, Val acc 15.215%
# Ep 3 (Step 015600): Train loss 5.077, Val loss 5.214, Train acc 16.230%, Val acc 15.254%
# Ep 3 (Step 015700): Train loss 5.033, Val loss 5.206, Train acc 16.973%, Val acc 15.332%
# Ep 3 (Step 015800): Train loss 5.046, Val loss 5.200, Train acc 15.605%, Val acc 15.215%
# Ep 3 (Step 015900): Train loss 4.976, Val loss 5.199, Train acc 16.387%, Val acc 15.020%
# Ep 3 (Step 016000): Train loss 5.093, Val loss 5.191, Train acc 16.973%, Val acc 15.410%
# Ep 3 (Step 016100): Train loss 5.081, Val loss 5.183, Train acc 16.816%, Val acc 15.391%
# Ep 3 (Step 016200): Train loss 5.050, Val loss 5.184, Train acc 16.934%, Val acc 15.469%
# Ep 3 (Step 016300): Train loss 5.034, Val loss 5.184, Train acc 16.895%, Val acc 15.352%
# Ep 3 (Step 016400): Train loss 5.007, Val loss 5.190, Train acc 16.094%, Val acc 15.547%
# Ep 3 (Step 016500): Train loss 4.994, Val loss 5.183, Train acc 15.918%, Val acc 15.488%
# Ep 3 (Step 016600): Train loss 4.984, Val loss 5.192, Train acc 16.465%, Val acc 15.273%
# Ep 3 (Step 016700): Train loss 4.993, Val loss 5.187, Train acc 16.914%, Val acc 15.566%
# Ep 3 (Step 016800): Train loss 5.036, Val loss 5.177, Train acc 15.996%, Val acc 15.469%
# Ep 3 (Step 016900): Train loss 5.039, Val loss 5.187, Train acc 16.738%, Val acc 15.020%
# Ep 3 (Step 017000): Train loss 5.008, Val loss 5.182, Train acc 16.543%, Val acc 15.059%
# Ep 3 (Step 017100): Train loss 5.016, Val loss 5.177, Train acc 17.266%, Val acc 15.195%
# Ep 3 (Step 017200): Train loss 4.976, Val loss 5.178, Train acc 16.523%, Val acc 14.961%
# Ep 3 (Step 017300): Train loss 4.987, Val loss 5.167, Train acc 17.051%, Val acc 15.215%
# Ep 3 (Step 017400): Train loss 5.050, Val loss 5.179, Train acc 16.875%, Val acc 14.844%
# Ep 3 (Step 017500): Train loss 5.074, Val loss 5.159, Train acc 16.738%, Val acc 15.469%
# Ep 3 (Step 017600): Train loss 4.979, Val loss 5.160, Train acc 16.387%, Val acc 15.332%
# Ep 3 (Step 017700): Train loss 5.041, Val loss 5.156, Train acc 16.074%, Val acc 15.352%

# %% [markdown]
# ## 6. 시각화
#
# 중간 evaluation loss 곡선과 최종 train/val loss를 시각화합니다.

# %%
import matplotlib.pyplot as plt

if "PRETRAIN_ARTIFACTS" not in globals():
    raise RuntimeError("Run the training cell above first.")

metric_steps = PRETRAIN_ARTIFACTS["metric_steps"]
train_losses = PRETRAIN_ARTIFACTS["train_losses"]
val_losses = PRETRAIN_ARTIFACTS["val_losses"]
train_accs = PRETRAIN_ARTIFACTS["train_accs"]
val_accs = PRETRAIN_ARTIFACTS["val_accs"]
steps_per_epoch = len(PRETRAIN_ARTIFACTS["train_loader"])
metric_epochs = [step / steps_per_epoch for step in metric_steps] if steps_per_epoch else metric_steps

if train_losses and val_losses:
    plt.figure(figsize=(8, 4))
    plt.plot(metric_epochs, train_losses, label="Train loss")
    plt.plot(metric_epochs, val_losses, label="Val loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Train / Validation Loss")
    plt.legend()
    plt.show()
else:
    print("No intermediate loss points yet. Try lowering eval_freq.")

if train_accs and val_accs:
    plt.figure(figsize=(8, 4))
    plt.plot(metric_epochs, train_accs, label="Train acc")
    plt.plot(metric_epochs, val_accs, label="Val acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title("Train / Validation Accuracy")
    plt.legend()
    plt.show()
else:
    print("No intermediate accuracy points yet. Try lowering eval_freq.")

plt.figure(figsize=(5, 4))
plt.bar(
    ["final train loss", "final val loss"],
    [PRETRAIN_ARTIFACTS["final_train_loss"], PRETRAIN_ARTIFACTS["final_val_loss"]],
)
plt.ylabel("Loss")
plt.title("Final Evaluation Loss")
plt.show()

plt.figure(figsize=(5, 4))
plt.bar(
    ["final train acc", "final val acc"],
    [PRETRAIN_ARTIFACTS["final_train_acc"], PRETRAIN_ARTIFACTS["final_val_acc"]],
)
plt.ylabel("Accuracy")
plt.title("Final Evaluation Accuracy")
plt.show()

print("checkpoint:", PRETRAIN_ARTIFACTS["checkpoint_path"])
# Out:
# checkpoint: C:\Jungle\Jungle_GPT_lab\checkpoints\quick_pretrain_final.pt
